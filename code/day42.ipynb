# %%
from tensorflow.python.keras.callbacks import TensorBoard

# %%
NAME = "Cats-vs-dogs-CNN"
tensorboard = TensorBoard(log_dir="../logs/{}".format(NAME))

# %%
import tensorflow as tf
from tensorflow.python.keras.datasets import cifar10
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
from tensorflow.python.keras.callbacks import TensorBoard

import pickle
import time

NAME = "Cats-vs-dogs-CNN"

pickle_in = open("../dataset/X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("../dataset/y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))

model.add(Dense(1))
model.add(Activation('sigmoid'))

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'],
              )

model.fit(X, y,
          batch_size=32,
          
          epochs=3,
          validation_split=0.3,
          callbacks=[tensorboard])
# Out:
# WARNING:tensorflow:From /home/wyw/anaconda3/envs/ml_learn/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Train on 17462 samples, validate on 7484 samples
# WARNING:tensorflow:From /home/wyw/anaconda3/envs/ml_learn/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/3
# 17462/17462 [==============================] - 58s 3ms/sample - loss: 0.6751 - acc: 0.6083 - val_loss: 0.6280 - val_acc: 0.6468
# Epoch 2/3
# 17462/17462 [==============================] - 56s 3ms/sample - loss: 0.6042 - acc: 0.6799 - val_loss: 0.5799 - val_acc: 0.7072
# Epoch 3/3
# 17462/17462 [==============================] - 55s 3ms/sample - loss: 0.5388 - acc: 0.7333 - val_loss: 0.5566 - val_acc: 0.7262

# %%
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
from tensorflow.python.keras.callbacks import TensorBoard

import pickle
import time
NAME = "Cats-vs-dogs-64x2-CNN"

pickle_in = open("../dataset/X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("../dataset/y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

model = Sequential()

model.add(Conv2D(64, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # 展平
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

tensorboard = TensorBoard(log_dir="../logs/{}".format(NAME))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'],
              )
model.fit(X, y,
          batch_size=32,
          epochs=10,
          validation_split=0.3,
          callbacks=[tensorboard])
# Out:
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/10
# 17462/17462 [==============================] - 14s 798us/sample - loss: 0.6442 - acc: 0.6261 - val_loss: 0.5759 - val_acc: 0.7031
# Epoch 2/10
# 17462/17462 [==============================] - 14s 793us/sample - loss: 0.5263 - acc: 0.7358 - val_loss: 0.5045 - val_acc: 0.7544
# Epoch 3/10
# 17462/17462 [==============================] - 14s 775us/sample - loss: 0.4442 - acc: 0.7918 - val_loss: 0.4875 - val_acc: 0.7644
# Epoch 4/10
# 17462/17462 [==============================] - 14s 794us/sample - loss: 0.3591 - acc: 0.8416 - val_loss: 0.5631 - val_acc: 0.7336
# Epoch 5/10
# 17462/17462 [==============================] - 14s 800us/sample - loss: 0.2574 - acc: 0.8938 - val_loss: 0.5517 - val_acc: 0.7674
# Epoch 6/10
# 17462/17462 [==============================] - 14s 808us/sample - loss: 0.1460 - acc: 0.9461 - val_loss: 0.6815 - val_acc: 0.7722
# Epoch 7/10
# 17462/17462 [==============================] - 14s 804us/sample - loss: 0.0751 - acc: 0.9764 - val_loss: 0.8861 - val_acc: 0.7667
# Epoch 8/10
# 17462/17462 [==============================] - 14s 805us/sample - loss: 0.0365 - acc: 0.9893 - val_loss: 0.9971 - val_acc: 0.7671
# Epoch 9/10
# 17462/17462 [==============================] - 14s 784us/sample - loss: 0.0201 - acc: 0.9948 - val_loss: 1.1471 - val_acc: 0.7718
# Epoch 10/10
# 17462/17462 [==============================] - 14s 787us/sample - loss: 0.0269 - acc: 0.9923 - val_loss: 1.1981 - val_acc: 0.7587
